# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacgarcia2/Digitalizacion/blob/main/temperaturas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio para convertir temperaturas Celsius a Fahrenheit

# %%
kelvin = float(input('Dime la temperatura en ºC: '))
celsius = kelvin * (0) + 273,15
kelvin= 0 + 273,15
print('La temperatura de', kelvin,'ºC = ',celsius,'ºF')
# Out:
# Dime la temperatura en ºC: 34
# La temperatura de 34.0 ºC =  93.2 ºF

# %% [markdown]
# Completa el programa anterior para que también convierta los grados Celsius a grados Kelvin
